# %% [markdown]
# # Scraping imdb Top 250 Info

# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import requests

# %%
url = "https://www.imdb.com/list/ls055386972/"
response = requests.get(url, headers={"Accept-Lanuage":"en-US"})
soup = BeautifulSoup(response.content, "html.parser")

# %%
movies = []
for movie in soup.find_all("div", class_="lister-item-content"):
    title = movie.find("h3").find("a").string
    duration = int(movie.find(class_="runtime").string.strip(' min'))
    year = int(re.search(r"\d{4}", movie.find(class_="lister-item-year").string).group(0))
    movies.append({'title': title, 'duration': duration, 'year': year})
movies[0]
# Out:
# {'title': 'Der Pate', 'duration': 175, 'year': 1972}

# %%
# converting list to dataframe
movies_df = pd.DataFrame(movies)
movies_df.head()
# Out:
#                       title  duration  year
# 0                  Der Pate       175  1972
# 1          Schindlers Liste       195  1993
# 2       Die 12 Geschworenen        96  1957
# 3           La vita è bella       116  1997
# 4  Zwei glorreiche Halunken       161  1966

# %%
# scraping all pages of the Top250
def fetch_page(page):
    response = requests.get(
        "https://www.imdb.com/search/title/",
        params={"groups":"top_250", "sort":"user_rating","start": (1 + page * 50)},
        headers={"Accept-Language":"en-US"})
    soup = BeautifulSoup(response.content, "html.parser")
    return soup

# %%
def parse_movies(soup):
    movies = []
    for movie in soup.find_all("div", class_="lister-item-content"):
        title = movie.find("h3").find("a").string
        duration = int(movie.find(class_="runtime").string.strip(' min'))
        year = int(re.search(r"\d{4}", movie.find(class_="lister-item-year").string).group(0))
        movies.append({'title': title, 'duration': duration, 'year': year})
    return movies

# %%
all_movies = []
for page in range(5):
    print(f"Parsing page {page + 1}...")
    soup = fetch_page(page)
    all_movies += parse_movies(soup)
print("Done")
# Out:
# Parsing page 1...
# Parsing page 2...
# Parsing page 3...
# Parsing page 4...
# Parsing page 5...
# Done

# %%
all_movies
# Out:
# [{'title': 'The Shawshank Redemption', 'duration': 142, 'year': 1994},
#  {'title': 'The Godfather', 'duration': 175, 'year': 1972},
#  {'title': 'The Dark Knight', 'duration': 152, 'year': 2008},
#  {'title': "Schindler's List", 'duration': 195, 'year': 1993},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'duration': 201,
#   'year': 2003},
#  {'title': '12 Angry Men', 'duration': 96, 'year': 1957},
#  {'title': 'The Godfather Part II', 'duration': 202, 'year': 1974},
#  {'title': 'Pulp Fiction', 'duration': 154, 'year': 1994},
#  {'title': 'Inception', 'duration': 148, 'year': 2010},
#  {'title': 'Fight Club', 'duration': 139, 'year': 1999},
#  {'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'duration': 178,
#   'year': 2001},
#  {'title': 'Forrest Gump', 'duration': 142, 'year': 1994},
#  {'title': 'The Good, the Bad and the Ugly', 'duration': 178, 'year': 1966},
#  {'title': 'The Lord of the Rings: The Two Towers',
#   'duration': 179,
#   'year': 2002},
#  {'title': 'Jai Bhim', 'duration': 164, 'year': 2021},
#  {'title': 'The Matrix', 'duration': 136, 'year': 1999},
#  {'title': 'Goodfellas', 'duration': 145, 'year': 1990},
#  {'title': "One Flew Over the Cuckoo's Nest", 'duration': 133, 'year': 1975},
#  {'title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'duration': 124,
#   'year': 1980},
#  {'title': 'Interstellar', 'duration': 169, 'year': 2014},
#  {'title': 'The Silence of the Lambs', 'duration': 118, 'year': 1991},
#  {'title': 'Se7en', 'duration': 127, 'year': 1995},
#  {'title': 'Star Wars: Episode IV - A New Hope',
#   'duration': 121,
#   'year': 1977},
#  {'title': 'The Green Mile', 'duration': 189, 'year': 1999},
#  {'title': 'Spirited Away', 'duration': 125, 'year': 2001},
#  {'title': 'Saving Private Ryan', 'duration': 169, 'year': 1998},
#  {'title': 'Terminator 2: Judgment Day', 'duration': 137, 'year': 1991},
#  {'title': 'City of God', 'duration': 130, 'year': 2002},
#  {'title': 'Life Is Beautiful', 'duration': 116, 'year': 1997},
#  {'title': 'Seven Samurai', 'duration': 207, 'year': 1954},
#  {'title': "It's a Wonderful Life", 'duration': 130, 'year': 1946},
#  {'title': 'Harakiri', 'duration': 133, 'year': 1962},
#  {'title': 'Alien', 'duration': 117, 'year': 1979},
#  {'title': 'Whiplash', 'duration': 106, 'year': 2014},
#  {'title': 'Gladiator', 'duration': 155, 'year': 2000},
#  {'title': 'Parasite', 'duration': 132, 'year': 2019},
#  {'title': 'Back to the Future', 'duration': 116, 'year': 1985},
#  {'title': 'The Departed', 'duration': 151, 'year': 2006},
#  {'title': 'The Prestige', 'duration': 130, 'year': 2006},
#  {'title': 'Léon: The Professional', 'duration': 110, 'year': 1994},
#  {'title': 'The Lion King', 'duration': 88, 'year': 1994},
#  {'title': 'Apocalypse Now', 'duration': 147, 'year': 1979},
#  {'title': 'The Pianist', 'duration': 150, 'year': 2002},
#  {'title': 'Psycho', 'duration': 109, 'year': 1960},
#  {'title': 'The Usual Suspects', 'duration': 106, 'year': 1995},
#  {'title': 'Casablanca', 'duration': 102, 'year': 1942},
#  {'title': 'American History X', 'duration': 119, 'year': 1998},
#  {'title': 'The Intouchables', 'duration': 112, 'year': 2011},
#  {'title': 'Once Upon a Time in the West', 'duration': 165, 'year': 1968},
#  {'title': 'Grave of the Fireflies', 'duration': 89, 'year': 1988},
#  {'title': 'Cinema Paradiso', 'duration': 155, 'year': 1988},
#  {'title': 'Rear Window', 'duration': 112, 'year': 1954},
#  {'title': 'Modern Times', 'duration': 87, 'year': 1936},
#  {'title': 'City Lights', 'duration': 87, 'year': 1931},
#  {'title': 'Avengers: Endgame', 'duration': 181, 'year': 2019},
#  {'title': 'Joker', 'duration': 122, 'year': 2019},
#  {'title': 'Spider-Man: Into the Spider-Verse', 'duration': 117, 'year': 2018},
#  {'title': 'Raiders of the Lost Ark', 'duration': 115, 'year': 1981},
#  {'title': 'Your Name.', 'duration': 106, 'year': 2016},
#  {'title': 'Aliens', 'duration': 137, 'year': 1986},
#  {'title': 'Avengers: Infinity War', 'duration': 149, 'year': 2018},
#  {'title': 'Django Unchained', 'duration': 165, 'year': 2012},
#  {'title': 'The Shining', 'duration': 146, 'year': 1980},
#  {'title': 'Oldboy', 'duration': 120, 'year': 2003},
#  {'title': 'The Dark Knight Rises', 'duration': 164, 'year': 2012},
#  {'title': 'Memento', 'duration': 113, 'year': 2000},
#  {'title': 'Come and See', 'duration': 142, 'year': 1985},
#  {'title': 'Braveheart', 'duration': 178, 'year': 1995},
#  {'title': 'Das Boot', 'duration': 149, 'year': 1981},
#  {'title': 'WALL·E', 'duration': 98, 'year': 2008},
#  {'title': 'Coco', 'duration': 105, 'year': 2017},
#  {'title': 'Amadeus', 'duration': 160, 'year': 1984},
#  {'title': 'The Lives of Others', 'duration': 137, 'year': 2006},
#  {'title': 'Capernaum', 'duration': 126, 'year': 2018},
#  {'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'duration': 95,
#   'year': 1964},
#  {'title': 'Sunset Blvd.', 'duration': 110, 'year': 1950},
#  {'title': '3 Idiots', 'duration': 170, 'year': 2009},
#  {'title': 'Witness for the Prosecution', 'duration': 116, 'year': 1957},
#  {'title': 'Paths of Glory', 'duration': 88, 'year': 1957},
#  {'title': 'The Great Dictator', 'duration': 125, 'year': 1940},
#  {'title': 'High and Low', 'duration': 143, 'year': 1963},
#  {'title': 'Top Gun: Maverick', 'duration': 130, 'year': 2022},
#  {'title': 'Good Will Hunting', 'duration': 126, 'year': 1997},
#  {'title': 'Inglourious Basterds', 'duration': 153, 'year': 2009},
#  {'title': 'Requiem for a Dream', 'duration': 102, 'year': 2000},
#  {'title': 'Heat', 'duration': 170, 'year': 1995},
#  {'title': 'Scarface', 'duration': 170, 'year': 1983},
#  {'title': 'Star Wars: Episode VI - Return of the Jedi',
#   'duration': 131,
#   'year': 1983},
#  {'title': 'American Beauty', 'duration': 122, 'year': 1999},
#  {'title': 'A Clockwork Orange', 'duration': 136, 'year': 1971},
#  {'title': 'Full Metal Jacket', 'duration': 116, 'year': 1987},
#  {'title': 'Eternal Sunshine of the Spotless Mind',
#   'duration': 108,
#   'year': 2004},
#  {'title': '2001: A Space Odyssey', 'duration': 149, 'year': 1968},
#  {'title': 'The Hunt', 'duration': 115, 'year': 2012},
#  {'title': 'Hamilton', 'duration': 160, 'year': 2020},
#  {'title': 'Reservoir Dogs', 'duration': 99, 'year': 1992},
#  {'title': 'Toy Story', 'duration': 81, 'year': 1995},
#  {'title': 'Vertigo', 'duration': 128, 'year': 1958},
#  {'title': 'Once Upon a Time in America', 'duration': 229, 'year': 1984},
#  {'title': 'Up', 'duration': 96, 'year': 2009},
#  {'title': 'Citizen Kane', 'duration': 119, 'year': 1941},
#  {'title': 'Amélie', 'duration': 122, 'year': 2001},
#  {'title': 'Incendies', 'duration': 131, 'year': 2010},
#  {'title': 'Princess Mononoke', 'duration': 134, 'year': 1997},
#  {'title': 'To Kill a Mockingbird', 'duration': 129, 'year': 1962},
#  {'title': 'Toy Story 3', 'duration': 103, 'year': 2010},
#  {'title': 'The Sting', 'duration': 129, 'year': 1973},
#  {'title': 'Lawrence of Arabia', 'duration': 218, 'year': 1962},
#  {'title': 'North by Northwest', 'duration': 136, 'year': 1959},
#  {'title': 'Metropolis', 'duration': 153, 'year': 1927},
#  {'title': "Singin' in the Rain", 'duration': 103, 'year': 1952},
#  {'title': 'A Separation', 'duration': 123, 'year': 2011},
#  {'title': 'Dangal', 'duration': 161, 'year': 2016},
#  {'title': 'The Apartment', 'duration': 125, 'year': 1960},
#  {'title': 'M', 'duration': 99, 'year': 1931},
#  {'title': 'Ikiru', 'duration': 143, 'year': 1952},
#  {'title': 'Judgment at Nuremberg', 'duration': 179, 'year': 1961},
#  {'title': 'Double Indemnity', 'duration': 107, 'year': 1944},
#  {'title': 'Like Stars on Earth', 'duration': 165, 'year': 2007},
#  {'title': 'Bicycle Thieves', 'duration': 89, 'year': 1948},
#  {'title': 'The Kid', 'duration': 68, 'year': 1921},
#  {'title': 'John Wick: Chapter 4', 'duration': 169, 'year': 2023},
#  {'title': 'The Wolf of Wall Street', 'duration': 180, 'year': 2013},
#  {'title': 'Spider-Man: No Way Home', 'duration': 148, 'year': 2021},
#  {'title': 'Jurassic Park', 'duration': 127, 'year': 1993},
#  {'title': 'Taxi Driver', 'duration': 114, 'year': 1976},
#  {'title': '1917', 'duration': 119, 'year': 2019},
#  {'title': 'Shutter Island', 'duration': 138, 'year': 2010},
#  {'title': 'No Country for Old Men', 'duration': 122, 'year': 2007},
#  {'title': 'Indiana Jones and the Last Crusade',
#   'duration': 127,
#   'year': 1989},
#  {'title': 'Unforgiven', 'duration': 130, 'year': 1992},
#  {'title': 'Finding Nemo', 'duration': 100, 'year': 2003},
#  {'title': 'Green Book', 'duration': 130, 'year': 2018},
#  {'title': 'The Thing', 'duration': 109, 'year': 1982},
#  {'title': 'Kill Bill: Vol. 1', 'duration': 111, 'year': 2003},
#  {'title': 'There Will Be Blood', 'duration': 158, 'year': 2007},
#  {'title': "Howl's Moving Castle", 'duration': 119, 'year': 2004},
#  {'title': 'Batman Begins', 'duration': 140, 'year': 2005},
#  {'title': 'Casino', 'duration': 178, 'year': 1995},
#  {'title': 'The Sixth Sense', 'duration': 107, 'year': 1999},
#  {'title': 'The Truman Show', 'duration': 103, 'year': 1998},
#  {'title': 'Snatch', 'duration': 102, 'year': 2000},
#  {'title': 'A Beautiful Mind', 'duration': 135, 'year': 2001},
#  {'title': 'L.A. Confidential', 'duration': 138, 'year': 1997},
#  {'title': 'Die Hard', 'duration': 132, 'year': 1988},
#  {'title': 'The Father', 'duration': 97, 'year': 2020},
#  {'title': 'Downfall', 'duration': 156, 'year': 2004},
#  {'title': 'Gone with the Wind', 'duration': 238, 'year': 1939},
#  {'title': 'Chinatown', 'duration': 130, 'year': 1974},
#  {'title': "Pan's Labyrinth", 'duration': 118, 'year': 2006},
#  {'title': 'V for Vendetta', 'duration': 132, 'year': 2005},
#  {'title': 'Warrior', 'duration': 140, 'year': 2011},
#  {'title': 'Monty Python and the Holy Grail', 'duration': 91, 'year': 1975},
#  {'title': 'Some Like It Hot', 'duration': 121, 'year': 1959},
#  {'title': 'The Great Escape', 'duration': 172, 'year': 1963},
#  {'title': 'The Secret in Their Eyes', 'duration': 129, 'year': 2009},
#  {'title': 'The Elephant Man', 'duration': 124, 'year': 1980},
#  {'title': 'Ran', 'duration': 162, 'year': 1985},
#  {'title': 'For a Few Dollars More', 'duration': 132, 'year': 1965},
#  {'title': 'All About Eve', 'duration': 138, 'year': 1950},
#  {'title': 'Dial M for Murder', 'duration': 105, 'year': 1954},
#  {'title': 'The Treasure of the Sierra Madre', 'duration': 126, 'year': 1948},
#  {'title': 'Klaus', 'duration': 96, 'year': 2019},
#  {'title': 'Yojimbo', 'duration': 110, 'year': 1961},
#  {'title': 'Rashomon', 'duration': 88, 'year': 1950},
#  {'title': 'Children of Heaven', 'duration': 89, 'year': 1997},
#  {'title': 'Tokyo Story', 'duration': 136, 'year': 1953},
#  {'title': 'Pather Panchali', 'duration': 125, 'year': 1955},
#  {'title': 'The Wages of Fear', 'duration': 131, 'year': 1953},
#  {'title': 'The Passion of Joan of Arc', 'duration': 114, 'year': 1928},
#  {'title': 'To Be or Not to Be', 'duration': 99, 'year': 1942},
#  {'title': 'Dersu Uzala', 'duration': 142, 'year': 1975},
#  {'title': 'My Father and My Son', 'duration': 112, 'year': 2005},
#  {'title': 'Sherlock Jr.', 'duration': 45, 'year': 1924},
#  {'title': 'The Exorcist', 'duration': 122, 'year': 1973},
#  {'title': 'The Help', 'duration': 146, 'year': 2011},
#  {'title': 'Prisoners', 'duration': 153, 'year': 2013},
#  {'title': 'The Grand Budapest Hotel', 'duration': 99, 'year': 2014},
#  {'title': 'Ford v Ferrari', 'duration': 152, 'year': 2019},
#  {'title': 'Stand by Me', 'duration': 89, 'year': 1986},
#  {'title': 'Mad Max: Fury Road', 'duration': 120, 'year': 2015},
#  {'title': 'The Big Lebowski', 'duration': 117, 'year': 1998},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'duration': 143,
#   'year': 2003},
#  {'title': 'Hacksaw Ridge', 'duration': 139, 'year': 2016},
#  {'title': 'Gone Girl', 'duration': 149, 'year': 2014},
#  {'title': 'Blade Runner', 'duration': 117, 'year': 1982},
#  {'title': 'Jaws', 'duration': 124, 'year': 1975},
#  {'title': 'Logan', 'duration': 137, 'year': 2017},
#  {'title': 'The Wizard of Oz', 'duration': 102, 'year': 1939},
#  {'title': 'Catch Me If You Can', 'duration': 141, 'year': 2002},
#  {'title': 'Rocky', 'duration': 120, 'year': 1976},
#  {'title': 'The Terminator', 'duration': 107, 'year': 1984},
#  {'title': 'The Handmaiden', 'duration': 145, 'year': 2016},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'duration': 130,
#   'year': 2011},
#  {'title': 'Ratatouille', 'duration': 111, 'year': 2007},
#  {'title': 'Dead Poets Society', 'duration': 128, 'year': 1989},
#  {'title': 'Trainspotting', 'duration': 93, 'year': 1996},
#  {'title': 'Fargo', 'duration': 98, 'year': 1996},
#  {'title': 'Inside Out', 'duration': 95, 'year': 2015},
#  {'title': 'Into the Wild', 'duration': 148, 'year': 2007},
#  {'title': 'How to Train Your Dragon', 'duration': 98, 'year': 2010},
#  {'title': 'Lock, Stock and Two Smoking Barrels',
#   'duration': 107,
#   'year': 1998},
#  {'title': 'Spotlight', 'duration': 129, 'year': 2015},
#  {'title': 'Three Billboards Outside Ebbing, Missouri',
#   'duration': 115,
#   'year': 2017},
#  {'title': 'Room', 'duration': 118, 'year': 2015},
#  {'title': 'Before Sunrise', 'duration': 101, 'year': 1995},
#  {'title': 'Gran Torino', 'duration': 116, 'year': 2008},
#  {'title': 'Monsters, Inc.', 'duration': 92, 'year': 2001},
#  {'title': 'Memories of Murder', 'duration': 132, 'year': 2003},
#  {'title': 'Platoon', 'duration': 120, 'year': 1986},
#  {'title': 'The Sound of Music', 'duration': 172, 'year': 1965},
#  {'title': 'The Deer Hunter', 'duration': 183, 'year': 1978},
#  {'title': '12 Years a Slave', 'duration': 134, 'year': 2013},
#  {'title': 'Rush', 'duration': 123, 'year': 2013},
#  {'title': 'Barry Lyndon', 'duration': 185, 'year': 1975},
#  {'title': 'Raging Bull', 'duration': 129, 'year': 1980},
#  {'title': 'Million Dollar Baby', 'duration': 132, 'year': 2004},
#  {'title': 'Ben-Hur', 'duration': 212, 'year': 1959},
#  {'title': 'My Neighbor Totoro', 'duration': 86, 'year': 1988},
#  {'title': 'Cool Hand Luke', 'duration': 127, 'year': 1967},
#  {'title': 'La haine', 'duration': 98, 'year': 1995},
#  {'title': "Hachi: A Dog's Tale", 'duration': 93, 'year': 2009},
#  {'title': 'Wild Tales', 'duration': 122, 'year': 2014},
#  {'title': 'Before Sunset', 'duration': 80, 'year': 2004},
#  {'title': 'Network', 'duration': 121, 'year': 1976},
#  {'title': 'The Seventh Seal', 'duration': 96, 'year': 1957},
#  {'title': 'The Iron Giant', 'duration': 86, 'year': 1999},
#  {'title': 'Amores Perros', 'duration': 154, 'year': 2000},
#  {'title': 'Hotel Rwanda', 'duration': 121, 'year': 2004},
#  {'title': 'The Bridge on the River Kwai', 'duration': 161, 'year': 1957},
#  {'title': 'Persona', 'duration': 83, 'year': 1966},
#  {'title': 'In the Name of the Father', 'duration': 133, 'year': 1993},
#  {'title': 'Rebecca', 'duration': 130, 'year': 1940},
#  {'title': 'The Third Man', 'duration': 93, 'year': 1949},
#  {'title': 'Mary and Max', 'duration': 92, 'year': 2009},
#  {'title': 'On the Waterfront', 'duration': 108, 'year': 1954},
#  {'title': 'The Best Years of Our Lives', 'duration': 170, 'year': 1946},
#  {'title': 'The Grapes of Wrath', 'duration': 129, 'year': 1940},
#  {'title': 'It Happened One Night', 'duration': 105, 'year': 1934},
#  {'title': 'The 400 Blows', 'duration': 99, 'year': 1959},
#  {'title': 'Wild Strawberries', 'duration': 91, 'year': 1957},
#  {'title': 'The Battle of Algiers', 'duration': 121, 'year': 1966},
#  {'title': 'Mr. Smith Goes to Washington', 'duration': 129, 'year': 1939},
#  {'title': 'The General', 'duration': 67, 'year': 1926},
#  {'title': 'The Gold Rush', 'duration': 95, 'year': 1925},
#  {'title': 'The Incredibles', 'duration': 115, 'year': 2004},
#  {'title': 'Dances with Wolves', 'duration': 181, 'year': 1990},
#  {'title': 'Groundhog Day', 'duration': 101, 'year': 1993},
#  {'title': 'Aladdin', 'duration': 90, 'year': 1992},
#  {'title': 'Life of Brian', 'duration': 94, 'year': 1979}]

# %%
all_movies_df = pd.DataFrame(all_movies)

# %%
all_movies_df.head()
# Out:
#                                            title  duration  year
# 0                       The Shawshank Redemption       142  1994
# 1                                  The Godfather       175  1972
# 2                                The Dark Knight       152  2008
# 3                               Schindler's List       195  1993
# 4  The Lord of the Rings: The Return of the King       201  2003
